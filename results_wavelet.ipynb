# %%
import pandas as pd
import numpy as np
agg = pd.read_csv("aggregated_metrics.csv")
wave = agg[agg["model"] == "Wavelet"].set_index("group")

display(wave[["tp", "fp", "fn", "tn", "precision", "recall", "f1", "accuracy"]])
# Out:
#                                                tp  fp  fn  tn  precision  \
# group
# Variant - Two clearly separated peaks           0   0   0  10       1.00
# Variant - Strong overlap between two peaks      1   0   4   0       1.00
# Variant - Four peaks: 2 overlap, 2 isolated     5   1   0   9       0.83
# Variant - Cluster of 3 overlapping peaks        5   0   0   0       1.00
# Variant - Close but not overlapping peaks       0   1   0   9       0.00
# Variant - Intense + weak overlap                4   0   1   5       1.00
# Variant - Five peaks: 3 spaced, 2 overlapping   0   5   5  10       0.00
#
#                                                recall    f1  accuracy
# group
# Variant - Two clearly separated peaks             1.0  1.00      1.00
# Variant - Strong overlap between two peaks        0.2  0.33      0.20
# Variant - Four peaks: 2 overlap, 2 isolated       1.0  0.91      0.93
# Variant - Cluster of 3 overlapping peaks          1.0  1.00      1.00
# Variant - Close but not overlapping peaks         1.0  0.00      0.90
# Variant - Intense + weak overlap                  0.8  0.89      0.90
# Variant - Five peaks: 3 spaced, 2 overlapping     0.0  0.00      0.50

# %%
confusion = wave[["tp", "fp", "fn", "tn"]]
print("Table X: Wavelet Confusion Matrix by Variant Group\n")
display(confusion)
# Out:
# Table X: Wavelet Confusion Matrix by Variant Group
#                                                tp  fp  fn  tn
# group
# Variant - Two clearly separated peaks           0   0   0  10
# Variant - Strong overlap between two peaks      1   0   4   0
# Variant - Four peaks: 2 overlap, 2 isolated     5   1   0   9
# Variant - Cluster of 3 overlapping peaks        5   0   0   0
# Variant - Close but not overlapping peaks       0   1   0   9
# Variant - Intense + weak overlap                4   0   1   5
# Variant - Five peaks: 3 spaced, 2 overlapping   0   5   5  10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

sns.heatmap(
    wave[["f1"]].rename(columns={"f1": "F1-score"}),
    annot=True, fmt=".2f", cmap="Blues", cbar=False, ax=ax1
)
ax1.set_title("Wavelet F₁-Score by Variant Group")
ax1.set_xlabel("")
ax1.set_ylabel("Variant Group")

sns.heatmap(
    wave[["accuracy"]].rename(columns={"accuracy": "Accuracy"}),
    annot=True, fmt=".2f", cmap="Greens", cbar=False, ax=ax2
)
ax2.set_title("Wavelet Accuracy by Variant Group")
ax2.set_xlabel("")
ax2.set_ylabel("")

plt.tight_layout()
plt.show()

# %%
region = pd.read_csv("region_results_full.csv")

wave_pc = region[(region["model"] == "Wavelet") & region["count_error"].notna()]
wave_le = region[(region["model"] == "Wavelet") & region["mean_loc_error"].notna()]

# Peak-count error barplot
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=wave_pc,
    x="group",
    y="count_error",
    ci="sd",
    color="mediumslateblue"
)
sns.stripplot(
    data=wave_pc,
    x="group",
    y="count_error",
    color="black",
    size=8,
    jitter=True
)
ax.set_title("Wavelet Absolute Peak‑Count Error (mean ± SD)")
ax.set_xlabel("Variant Group")
ax.set_ylabel("Absolute Count Error")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()

# Localization error barplot
summary_le_wave = wave_le.groupby("group")["mean_loc_error"].agg(["mean", "std"]).sort_values("mean")
order_le_wave = summary_le_wave.index.tolist()

plt.figure(figsize=(8, 6))
ax = sns.barplot(
    data=summary_le_wave.reset_index(),
    x="group",
    y="mean",
    order=order_le_wave,
    palette="Purples"
)
for i, (_, row) in enumerate(summary_le_wave.iterrows()):
    ax.errorbar(i, row["mean"], yerr=row["std"], color="k", capsize=3, lw=1)
    ax.text(i, row["mean"] + row["std"] + 0.0005, f"{row['mean']:.3f}±{row['std']:.3f}", ha="center", va="bottom", fontsize=9)
plt.title("Wavelet Mean m/z Localization Error by Variant Group")
plt.ylabel("Mean m/z Error ± SD")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()


print(wave_pc["count_error"])
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_15680\671600773.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.barplot(
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\victo\AppData\Local\Temp\ipykernel_15680\671600773.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# 4      1
# 5      1
# 10     1
# 11     1
# 16     1
#       ..
# 212    0
# 221    1
# 222    1
# 223    1
# 224    0
# Name: count_error, Length: 75, dtype: int64

# %%
stats_pc_wave = (
    wave_pc.groupby("group")["count_error"].agg(mean_count_error="mean", std_count_error="std")
)
stats_le_wave = (
    wave_le.groupby("group")["mean_loc_error"].agg(mean_loc_error="mean", std_loc_error="std")
)
stats_summary_wave = stats_pc_wave.join(stats_le_wave)
display(stats_summary_wave)
# Out:
#                                                mean_count_error  \
# group
# Variant - Close but not overlapping peaks              1.100000
# Variant - Cluster of 3 overlapping peaks               0.000000
# Variant - Five peaks: 3 spaced, 2 overlapping          0.750000
# Variant - Four peaks: 2 overlap, 2 isolated            0.666667
# Variant - Intense + weak overlap                       0.800000
# Variant - Strong overlap between two peaks             1.600000
# Variant - Two clearly separated peaks                  1.000000
#
#                                                std_count_error  \
# group
# Variant - Close but not overlapping peaks             0.316228
# Variant - Cluster of 3 overlapping peaks              0.000000
# Variant - Five peaks: 3 spaced, 2 overlapping         0.444262
# Variant - Four peaks: 2 overlap, 2 isolated           0.487950
# Variant - Intense + weak overlap                      0.632456
# Variant - Strong overlap between two peaks            0.894427
# Variant - Two clearly separated peaks                 0.000000
#
#                                                mean_loc_error  std_loc_error
# group
# Variant - Close but not overlapping peaks            0.005215       0.000191
# Variant - Cluster of 3 overlapping peaks             0.007614       0.001428
# Variant - Five peaks: 3 spaced, 2 overlapping        0.002490       0.003271
# Variant - Four peaks: 2 overlap, 2 isolated          0.002432       0.002643
# Variant - Intense + weak overlap                     0.003514       0.002818
# Variant - Strong overlap between two peaks           0.007758       0.006844
# Variant - Two clearly separated peaks                0.001491       0.000632

# %%
# Prepare a correctness label: TP/FP based on overlap_pred and overlap_true
wave_corr = region[(region["model"] == "Wavelet") & (region["overlap_pred"])]
wave_corr = wave_corr[wave_corr["confidence"].notna()].copy()
wave_corr['correctness'] = np.where(
    (wave_corr['overlap_true']) & (wave_corr['overlap_pred']), "TP",
    np.where((~wave_corr['overlap_true']) & (wave_corr['overlap_pred']), "FP", "Other")
)
wave_corr = wave_corr[wave_corr['correctness'].isin(["TP", "FP"])]

plt.figure(figsize=(6, 5))
sns.stripplot(data=wave_corr, x="correctness", y="confidence", jitter=True, hue="correctness", palette="Set2", dodge=False, size=8, alpha=0.7)
sns.boxplot(data=wave_corr, x="correctness", y="confidence", whis=[0, 100], width=0.3, showcaps=False, boxprops={'facecolor':'None'}, showfliers=False)
plt.title("Wavelet Confidence Score by Flag Correctness")
plt.xlabel("Flag Correctness")
plt.ylabel("Wavelet Confidence")
plt.legend([],[], frameon=False)  # Hide duplicate legend
plt.tight_layout()
plt.show()

print(wave_corr)
# Out:
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
#                                              group  \
# 41      Variant - Strong overlap between two peaks
# 51     Variant - Four peaks: 2 overlap, 2 isolated
# 60     Variant - Four peaks: 2 overlap, 2 isolated
# 69     Variant - Four peaks: 2 overlap, 2 isolated
# 71     Variant - Four peaks: 2 overlap, 2 isolated
# 78     Variant - Four peaks: 2 overlap, 2 isolated
# 87     Variant - Four peaks: 2 overlap, 2 isolated
# 92        Variant - Cluster of 3 overlapping peaks
# 95        Variant - Cluster of 3 overlapping peaks
# 98        Variant - Cluster of 3 overlapping peaks
# 101       Variant - Cluster of 3 overlapping peaks
# 104       Variant - Cluster of 3 overlapping peaks
# 109      Variant - Close but not overlapping peaks
# 139               Variant - Intense + weak overlap
# 151               Variant - Intense + weak overlap
# 157               Variant - Intense + weak overlap
# 163               Variant - Intense + weak overlap
# 176  Variant - Five peaks: 3 spaced, 2 overlapping
# 188  Variant - Five peaks: 3 spaced, 2 overlapping
# 200  Variant - Five peaks: 3 spaced, 2 overlapping
# 212  Variant - Five peaks: 3 spaced, 2 overlapping
# 224  Variant - Five peaks: 3 spaced, 2 overlapping
#
#                                                label    model  region_idx  \
# 41      Variant - Strong overlap between two peaks 4  Wavelet           0
# 51     Variant - Four peaks: 2 overlap, 2 isolated 1  Wavelet           0
# 60     Variant - Four peaks: 2 overlap, 2 isolated 2  Wavelet           0
# 69     Variant - Four peaks: 2 overlap, 2 isolated 3  Wavelet           0
# 71     Variant - Four peaks: 2 overlap, 2 isolated 3  Wavelet           2
# 78     Variant - Four peaks: 2 overlap, 2 isolated 4  Wavelet           0
# 87     Variant - Four peaks: 2 overlap, 2 isolated 5  Wavelet           0
# 92        Variant - Cluster of 3 overlapping peaks 1  Wavelet           0
# 95        Variant - Cluster of 3 overlapping peaks 2  Wavelet           0
# 98        Variant - Cluster of 3 overlapping peaks 3  Wavelet           0
# 101       Variant - Cluster of 3 overlapping peaks 4  Wavelet           0
# 104       Variant - Cluster of 3 overlapping peaks 5  Wavelet           0
# 109      Variant - Close but not overlapping peaks 1  Wavelet           0
# 139               Variant - Intense + weak overlap 1  Wavelet           0
# 151               Variant - Intense + weak overlap 3  Wavelet           0
# 157               Variant - Intense + weak overlap 4  Wavelet           0
# 163               Variant - Intense + weak overlap 5  Wavelet           0
# 176  Variant - Five peaks: 3 spaced, 2 overlapping 1  Wavelet           3
# 188  Variant - Five peaks: 3 spaced, 2 overlapping 2  Wavelet           3
# 200  Variant - Five peaks: 3 spaced, 2 overlapping 3  Wavelet           3
# 212  Variant - Five peaks: 3 spaced, 2 overlapping 4  Wavelet           3
# 224  Variant - Five peaks: 3 spaced, 2 overlapping 5  Wavelet           3
#
#      overlap_true  overlap_pred  count_error  mean_loc_error  confidence  \
# 41           True          True            0        0.019970      0.7767
# 51           True          True            0        0.001051      0.8965
# 60           True          True            0        0.001251      0.9343
# 69           True          True            0        0.000951      0.9283
# 71          False          True            1        0.000801      0.5703
# 78           True          True            0        0.001151      0.8736
# 87           True          True            0        0.000951      0.9258
# 92           True          True            0        0.006440      0.8921
# 95           True          True            0        0.006340      0.9607
# 98           True          True            0        0.009877      0.9340
# 101          True          True            0        0.007624      0.9272
# 104          True          True            0        0.007791      0.9222
# 109         False          True            2        0.005005      0.4813
# 139          True          True            0        0.007457      0.5986
# 151          True          True            0        0.007658      0.5994
# 157          True          True            1        0.007508      0.4770
# 163          True          True            0        0.002603      0.6170
# 176          True          True            0        0.014965      0.9063
# 188          True          True            0        0.004354      0.9861
# 200          True          True            0        0.005055      0.9520
# 212          True          True            0        0.004054      0.9439
# 224          True          True            0        0.004555      0.9910
#
#     bic_support  separation_score  confidence_percent_raw  \
# 41          NaN               NaN                     NaN
# 51          NaN               NaN                     NaN
# 60          NaN               NaN                     NaN
# 69          NaN               NaN                     NaN
# 71          NaN               NaN                     NaN
# 78          NaN               NaN                     NaN
# 87          NaN               NaN                     NaN
# 92          NaN               NaN                     NaN
# 95          NaN               NaN                     NaN
# 98          NaN               NaN                     NaN
# 101         NaN               NaN                     NaN
# 104         NaN               NaN                     NaN
# 109         NaN               NaN                     NaN
# 139         NaN               NaN                     NaN
# 151         NaN               NaN                     NaN
# 157         NaN               NaN                     NaN
# 163         NaN               NaN                     NaN
# 176         NaN               NaN                     NaN
# 188         NaN               NaN                     NaN
# 200         NaN               NaN                     NaN
# 212         NaN               NaN                     NaN
# 224         NaN               NaN                     NaN
#
#      confidence_percent_adjusted  fusion_score correctness
# 41                           NaN           NaN          TP
# 51                           NaN           NaN          TP
# 60                           NaN           NaN          TP
# 69                           NaN           NaN          TP
# 71                           NaN           NaN          FP
# 78                           NaN           NaN          TP
# 87                           NaN           NaN          TP
# 92                           NaN           NaN          TP
# 95                           NaN           NaN          TP
# 98                           NaN           NaN          TP
# 101                          NaN           NaN          TP
# 104                          NaN           NaN          TP
# 109                          NaN           NaN          FP
# 139                          NaN           NaN          TP
# 151                          NaN           NaN          TP
# 157                          NaN           NaN          TP
# 163                          NaN           NaN          TP
# 176                          NaN           NaN          TP
# 188                          NaN           NaN          TP
# 200                          NaN           NaN          TP
# 212                          NaN           NaN          TP
# 224                          NaN           NaN          TP

# %%
rw = region  # or re-load if you want
wave_all = rw[(rw["model"] == "Wavelet") & (rw["confidence"].notna())]

thresholds = np.linspace(wave_all['confidence'].min(), wave_all['confidence'].max(), 100)
precision, recall, f1 = [], [], []

for t in thresholds:
    pred = (wave_all['confidence'] >= t)
    tp = ((pred) & (wave_all['overlap_true'])).sum()
    fp = ((pred) & (~wave_all['overlap_true'])).sum()
    fn = ((~pred) & (wave_all['overlap_true'])).sum()
    prec = tp / (tp + fp) if (tp + fp) > 0 else np.nan
    rec = tp / (tp + fn) if (tp + fn) > 0 else np.nan
    precision.append(prec)
    recall.append(rec)
    f1.append(2 * prec * rec / (prec + rec) if prec + rec > 0 else np.nan)

precision = np.array(precision)
recall = np.array(recall)
f1 = np.array(f1)

best_idx = np.nanargmax(f1)
best_t = thresholds[best_idx]

plt.figure(figsize=(10, 4))
plt.plot(thresholds, precision, label='Precision', lw=2)
plt.plot(thresholds, recall, label='Recall', lw=2)
plt.plot(thresholds, f1, label='F1', linestyle="--", lw=1.5)
plt.fill_between(thresholds, precision, recall, color='purple', alpha=0.15, label='Precision-Recall Gap')

plt.axvline(x=best_t, color='k', linestyle='dashed')
plt.annotate(
    f"Best F1 = {f1[best_idx]:.2f}\nConfidence = {best_t:.2f}",
    xy=(best_t, f1[best_idx]),
    xytext=(best_t + (thresholds.max()-thresholds.min())*0.05, f1[best_idx] - 0.3),
    arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=3),
    fontsize=9,
    ha='left', va='center', weight='bold', color='black',
    bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="black", lw=1,)
)

plt.xlabel("Wavelet Confidence Threshold")
plt.ylabel("Score")
plt.title("Precision/Recall vs. Confidence Threshold (Wavelet)")
plt.legend(
    loc='center left',
    bbox_to_anchor=(1.01, 0.5),
    frameon=True,
    title='Legend'
)
plt.tight_layout(rect=[0,0,0.75,1])
plt.show()

print(f"Best F1 = {f1[best_idx]:.2f} at Confidence threshold {best_t:.2f}")
# Out:
# Best F1 = 0.50 at Confidence threshold 0.48

# %%
# Map scenario class (reuse your earlier mapping code)
agg["base_group"] = agg["group"].str.replace(r"^Variant -\s*", "", regex=True)
scenario_map = {
    "Two clearly separated peaks":        "Fully Separated",
    "Close but not overlapping peaks":     "Fully Separated",
    "Cluster of 3 overlapping peaks":      "Weakly Overlapping",
    "Four peaks: 2 overlap, 2 isolated":  "Weakly Overlapping",
    "Strong overlap between two peaks":    "Strongly Overlapping",
    "Intense + weak overlap":             "Asymmetric",
    "Five peaks: 3 spaced, 2 overlapping": "Near-Duplicates"
}
agg["scenario_class"] = agg["base_group"].map(scenario_map)
wave_agg = agg[agg["model"] == "Wavelet"]
tbl = (
    wave_agg
    .groupby("scenario_class")
    .agg({
        "tp":       "sum",
        "fp":       "sum",
        "fn":       "sum",
        "tn":       "sum",
        "f1":       "mean",
        "accuracy": "mean"
    })
    .reset_index()
)
tbl["f1"] = tbl["f1"].round(2)
tbl["accuracy"] = tbl["accuracy"].round(2)
display(tbl)
# Out:
#          scenario_class  tp  fp  fn  tn    f1  accuracy
# 0            Asymmetric   4   0   1   5  0.89      0.90
# 1       Fully Separated   0   1   0  19  0.50      0.95
# 2       Near-Duplicates   0   5   5  10  0.00      0.50
# 3  Strongly Overlapping   1   0   4   0  0.33      0.20
# 4    Weakly Overlapping  10   1   0   9  0.96      0.97

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# Prepare values and colormap
vals = tbl["f1"].values
norm = mpl.colors.Normalize(vmin=vals.min(), vmax=vals.max())
cmap = mpl.cm.Blues

plt.figure(figsize=(6, 4))
bars = plt.bar(
    tbl["scenario_class"],
    vals,
    color=cmap(norm(vals)),
    edgecolor="black"
)

# Extend y‐axis to make room for annotations
ymax = vals.max() * 1.15
plt.ylim(0, ymax)

plt.title("WVT F₁ by Scenario Category", pad=20)
plt.ylabel("F₁-Score")
plt.xlabel("")
plt.xticks(rotation=45, ha="right")

# Annotate bar values
for bar, h in zip(bars, vals):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        h + (ymax - h) * 0.02,
        f"{h:.2f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()


# %% 
# Color‐mapped, annotated GMM Accuracy by Scenario Category

acc_vals = tbl["accuracy"].values
norm_acc = mpl.colors.Normalize(vmin=acc_vals.min(), vmax=acc_vals.max())
cmap_acc = mpl.cm.Blues

plt.figure(figsize=(6, 4))
bars = plt.bar(
    tbl["scenario_class"],
    acc_vals,
    color=cmap_acc(norm_acc(acc_vals)),
    edgecolor="black"
)

ymax_acc = acc_vals.max() * 1.15
plt.ylim(0, ymax_acc)

plt.title("WVT Accuracy by Scenario Category", pad=20)
plt.ylabel("Accuracy")
plt.xlabel("")
plt.xticks(rotation=45, ha="right")

for bar, h in zip(bars, acc_vals):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        h + (ymax_acc - h) * 0.02,
        f"{h:.2f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()
