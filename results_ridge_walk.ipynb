# %%
# Cell 1: Load data & filter to GMM
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the aggregated metrics CSV
agg = pd.read_csv("aggregated_metrics.csv")

# Filter to only the RidgeWalker model
ridge = agg[agg["model"] == "RidgeWalker"].set_index("group")

# Display full RidgeWalker metrics
display(ridge[["tp", "fp", "fn", "tn", "precision", "recall", "f1", "accuracy"]])
# Out:
#                                                tp  fp  fn  tn  precision  \
# group
# Variant - Two clearly separated peaks           0   0   0  10       1.00
# Variant - Strong overlap between two peaks      5   0   0   0       1.00
# Variant - Four peaks: 2 overlap, 2 isolated     5   2   0   8       0.71
# Variant - Cluster of 3 overlapping peaks        5   0   0   0       1.00
# Variant - Close but not overlapping peaks       0   0   0  10       1.00
# Variant - Intense + weak overlap                3   1   2   4       0.75
# Variant - Five peaks: 3 spaced, 2 overlapping   0   5   5  10       0.00
#
#                                                recall    f1  accuracy
# group
# Variant - Two clearly separated peaks             1.0  1.00      1.00
# Variant - Strong overlap between two peaks        1.0  1.00      1.00
# Variant - Four peaks: 2 overlap, 2 isolated       1.0  0.83      0.87
# Variant - Cluster of 3 overlapping peaks          1.0  1.00      1.00
# Variant - Close but not overlapping peaks         1.0  1.00      1.00
# Variant - Intense + weak overlap                  0.6  0.67      0.70
# Variant - Five peaks: 3 spaced, 2 overlapping     0.0  0.00      0.50

# %%
confusion = ridge[["tp", "fp", "fn", "tn"]]
print("Table X: RidgeWalker Confusion Matrix by Variant Group\n")
display(confusion)
# Out:
# Table X: RidgeWalker Confusion Matrix by Variant Group
#                                                tp  fp  fn  tn
# group
# Variant - Two clearly separated peaks           0   0   0  10
# Variant - Strong overlap between two peaks      5   0   0   0
# Variant - Four peaks: 2 overlap, 2 isolated     5   2   0   8
# Variant - Cluster of 3 overlapping peaks        5   0   0   0
# Variant - Close but not overlapping peaks       0   0   0  10
# Variant - Intense + weak overlap                3   1   2   4
# Variant - Five peaks: 3 spaced, 2 overlapping   0   5   5  10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# F1‐score heatmap
sns.heatmap(
    ridge[["f1"]].rename(columns={"f1": "F1-score"}),
    annot=True, fmt=".2f", cmap="Blues", cbar=False, ax=ax1
)
ax1.set_title("RidgeWalker F₁-Score by Variant Group")
ax1.set_xlabel("")
ax1.set_ylabel("Variant Group")

# Accuracy heatmap
sns.heatmap(
    ridge[["accuracy"]].rename(columns={"accuracy": "Accuracy"}),
    annot=True, fmt=".2f", cmap="Greens", cbar=False, ax=ax2
)
ax2.set_title("RidgeWalker Accuracy by Variant Group")
ax2.set_xlabel("")
ax2.set_ylabel("")

plt.tight_layout()
plt.show()

# %%
region = pd.read_csv("region_results_full.csv")

# Filter to RidgeWalker
ridge_pc = region[(region["model"] == "RidgeWalker") & region["count_error"].notna()]
ridge_le = region[(region["model"] == "RidgeWalker") & region["mean_loc_error"].notna()]

# Mean ± SD, summarized by group
stats_pc_ridge = (
    ridge_pc
    .groupby("group")["count_error"]
    .agg(mean_count_error="mean", std_count_error="std")
)
stats_le_ridge = (
    ridge_le
    .groupby("group")["mean_loc_error"]
    .agg(mean_loc_error="mean", std_loc_error="std")
)
stats_summary_ridge = stats_pc_ridge.join(stats_le_ridge)
display(stats_summary_ridge)
# Out:
#                                                mean_count_error  \
# group
# Variant - Close but not overlapping peaks                  0.40
# Variant - Cluster of 3 overlapping peaks                   0.40
# Variant - Five peaks: 3 spaced, 2 overlapping              0.05
# Variant - Four peaks: 2 overlap, 2 isolated                0.20
# Variant - Intense + weak overlap                           0.50
# Variant - Strong overlap between two peaks                 0.40
# Variant - Two clearly separated peaks                      0.20
#
#                                                std_count_error  \
# group
# Variant - Close but not overlapping peaks             0.516398
# Variant - Cluster of 3 overlapping peaks              0.547723
# Variant - Five peaks: 3 spaced, 2 overlapping         0.223607
# Variant - Four peaks: 2 overlap, 2 isolated           0.414039
# Variant - Intense + weak overlap                      0.527046
# Variant - Strong overlap between two peaks            0.547723
# Variant - Two clearly separated peaks                 0.421637
#
#                                                mean_loc_error  std_loc_error
# group
# Variant - Close but not overlapping peaks            0.004815       0.000213
# Variant - Cluster of 3 overlapping peaks             0.003624       0.001109
# Variant - Five peaks: 3 spaced, 2 overlapping        0.001984       0.001612
# Variant - Four peaks: 2 overlap, 2 isolated          0.001458       0.000772
# Variant - Intense + weak overlap                     0.010991       0.019385
# Variant - Strong overlap between two peaks           0.011962       0.005707
# Variant - Two clearly separated peaks                0.001491       0.000632

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=ridge_pc,
    x="group",
    y="count_error",
    ci="sd",
    color="orange"
)
sns.stripplot(
    data=ridge_pc,
    x="group",
    y="count_error",
    color="black",
    size=8,
    jitter=True
)
ax.set_title("RidgeWalker Absolute Peak‑Count Error (mean ± SD)")
ax.set_xlabel("Variant Group")
ax.set_ylabel("Absolute Count Error")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_14880\2414274461.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.barplot(
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Order groups by mean error
summary_le_ridge = ridge_le.groupby("group")["mean_loc_error"].agg(["mean", "std"]).sort_values("mean")
order_le_ridge = summary_le_ridge.index.tolist()

plt.figure(figsize=(8, 6))
ax = sns.barplot(
    data=summary_le_ridge.reset_index(),
    x="group",
    y="mean",
    order=order_le_ridge,
    palette="Oranges"
)
for i, (_, row) in enumerate(summary_le_ridge.iterrows()):
    ax.errorbar(
        i, row["mean"],
        yerr=row["std"],
        color="k",
        capsize=3,
        lw=1
    )
    ax.text(
        i, row["mean"] + row["std"] + 0.0005,
        f"{row['mean']:.3f}±{row['std']:.3f}",
        ha="center", va="bottom", fontsize=9
    )
plt.title("RidgeWalker Mean m/z Localization Error by Variant Group")
plt.ylabel("Mean m/z Error ± SD")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_14880\3039360400.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7, 4))
sns.stripplot(data=rw, x="correctness", y="fusion_score", jitter=True, hue="correctness", palette="Set1", dodge=False, size=8, alpha=0.7)
plt.title("RidgeWalker Fusion Score by Flag Correctness")
plt.xlabel("Flag Correctness")
plt.ylabel("Fusion Score")
plt.legend([],[], frameon=False)  # Remove duplicate legend if you want
plt.tight_layout()
plt.show()

print(rw)
# Out:
# c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
#                                              group  \
# 31      Variant - Strong overlap between two peaks
# 34      Variant - Strong overlap between two peaks
# 37      Variant - Strong overlap between two peaks
# 40      Variant - Strong overlap between two peaks
# 43      Variant - Strong overlap between two peaks
# 48     Variant - Four peaks: 2 overlap, 2 isolated
# 49     Variant - Four peaks: 2 overlap, 2 isolated
# 57     Variant - Four peaks: 2 overlap, 2 isolated
# 59     Variant - Four peaks: 2 overlap, 2 isolated
# 66     Variant - Four peaks: 2 overlap, 2 isolated
# 75     Variant - Four peaks: 2 overlap, 2 isolated
# 84     Variant - Four peaks: 2 overlap, 2 isolated
# 91        Variant - Cluster of 3 overlapping peaks
# 94        Variant - Cluster of 3 overlapping peaks
# 97        Variant - Cluster of 3 overlapping peaks
# 100       Variant - Cluster of 3 overlapping peaks
# 103       Variant - Cluster of 3 overlapping peaks
# 137               Variant - Intense + weak overlap
# 144               Variant - Intense + weak overlap
# 149               Variant - Intense + weak overlap
# 155               Variant - Intense + weak overlap
# 172  Variant - Five peaks: 3 spaced, 2 overlapping
# 184  Variant - Five peaks: 3 spaced, 2 overlapping
# 196  Variant - Five peaks: 3 spaced, 2 overlapping
# 208  Variant - Five peaks: 3 spaced, 2 overlapping
# 220  Variant - Five peaks: 3 spaced, 2 overlapping
#
#                                                label        model  region_idx  \
# 31      Variant - Strong overlap between two peaks 1  RidgeWalker           0
# 34      Variant - Strong overlap between two peaks 2  RidgeWalker           0
# 37      Variant - Strong overlap between two peaks 3  RidgeWalker           0
# 40      Variant - Strong overlap between two peaks 4  RidgeWalker           0
# 43      Variant - Strong overlap between two peaks 5  RidgeWalker           0
# 48     Variant - Four peaks: 2 overlap, 2 isolated 1  RidgeWalker           0
# 49     Variant - Four peaks: 2 overlap, 2 isolated 1  RidgeWalker           1
# 57     Variant - Four peaks: 2 overlap, 2 isolated 2  RidgeWalker           0
# 59     Variant - Four peaks: 2 overlap, 2 isolated 2  RidgeWalker           2
# 66     Variant - Four peaks: 2 overlap, 2 isolated 3  RidgeWalker           0
# 75     Variant - Four peaks: 2 overlap, 2 isolated 4  RidgeWalker           0
# 84     Variant - Four peaks: 2 overlap, 2 isolated 5  RidgeWalker           0
# 91        Variant - Cluster of 3 overlapping peaks 1  RidgeWalker           0
# 94        Variant - Cluster of 3 overlapping peaks 2  RidgeWalker           0
# 97        Variant - Cluster of 3 overlapping peaks 3  RidgeWalker           0
# 100       Variant - Cluster of 3 overlapping peaks 4  RidgeWalker           0
# 103       Variant - Cluster of 3 overlapping peaks 5  RidgeWalker           0
# 137               Variant - Intense + weak overlap 1  RidgeWalker           0
# 144               Variant - Intense + weak overlap 2  RidgeWalker           1
# 149               Variant - Intense + weak overlap 3  RidgeWalker           0
# 155               Variant - Intense + weak overlap 4  RidgeWalker           0
# 172  Variant - Five peaks: 3 spaced, 2 overlapping 1  RidgeWalker           3
# 184  Variant - Five peaks: 3 spaced, 2 overlapping 2  RidgeWalker           3
# 196  Variant - Five peaks: 3 spaced, 2 overlapping 3  RidgeWalker           3
# 208  Variant - Five peaks: 3 spaced, 2 overlapping 4  RidgeWalker           3
# 220  Variant - Five peaks: 3 spaced, 2 overlapping 5  RidgeWalker           3
#
#      overlap_true  overlap_pred  count_error  mean_loc_error  confidence  \
# 31           True          True            0        0.019970         NaN
# 34           True          True            0        0.009960         NaN
# 37           True          True            0        0.009960         NaN
# 40           True          True            1        0.014965         NaN
# 43           True          True            1        0.004955         NaN
# 48           True          True            0        0.001051         NaN
# 49          False          True            1        0.002402         NaN
# 57           True          True            0        0.001251         NaN
# 59          False          True            0        0.001101         NaN
# 66           True          True            0        0.000951         NaN
# 75           True          True            0        0.001151         NaN
# 84           True          True            0        0.000951         NaN
# 91           True          True            0        0.003103         NaN
# 94           True          True            0        0.005606         NaN
# 97           True          True            0        0.003203         NaN
# 100          True          True            1        0.003053         NaN
# 103          True          True            1        0.003153         NaN
# 137          True          True            1        0.042593         NaN
# 144         False          True            1        0.001602         NaN
# 149          True          True            0        0.052402         NaN
# 155          True          True            1        0.002452         NaN
# 172          True          True            0        0.004154         NaN
# 184          True          True            0        0.004354         NaN
# 196          True          True            0        0.005756         NaN
# 208          True          True            0        0.004054         NaN
# 220          True          True            0        0.004555         NaN
#
#     bic_support  separation_score  confidence_percent_raw  \
# 31          NaN               NaN                     NaN
# 34          NaN               NaN                     NaN
# 37          NaN               NaN                     NaN
# 40          NaN               NaN                     NaN
# 43          NaN               NaN                     NaN
# 48          NaN               NaN                     NaN
# 49          NaN               NaN                     NaN
# 57          NaN               NaN                     NaN
# 59          NaN               NaN                     NaN
# 66          NaN               NaN                     NaN
# 75          NaN               NaN                     NaN
# 84          NaN               NaN                     NaN
# 91          NaN               NaN                     NaN
# 94          NaN               NaN                     NaN
# 97          NaN               NaN                     NaN
# 100         NaN               NaN                     NaN
# 103         NaN               NaN                     NaN
# 137         NaN               NaN                     NaN
# 144         NaN               NaN                     NaN
# 149         NaN               NaN                     NaN
# 155         NaN               NaN                     NaN
# 172         NaN               NaN                     NaN
# 184         NaN               NaN                     NaN
# 196         NaN               NaN                     NaN
# 208         NaN               NaN                     NaN
# 220         NaN               NaN                     NaN
#
#      confidence_percent_adjusted  fusion_score correctness
# 31                           NaN      0.533350          TP
# 34                           NaN      0.566687          TP
# 37                           NaN      0.540016          TP
# 40                           NaN      0.600066          TP
# 43                           NaN      0.700038          TP
# 48                           NaN      0.700052          TP
# 49                           NaN      0.700092          FP
# 57                           NaN      0.700027          TP
# 59                           NaN      0.700231          FP
# 66                           NaN      0.700022          TP
# 75                           NaN      0.600021          TP
# 84                           NaN      0.700349          TP
# 91                           NaN      0.700028          TP
# 94                           NaN      0.700089          TP
# 97                           NaN      0.700032          TP
# 100                          NaN      0.700043          TP
# 103                          NaN      0.700111          TP
# 137                          NaN      0.700719          TP
# 144                          NaN      0.700062          FP
# 149                          NaN      0.700021          TP
# 155                          NaN      0.700157          TP
# 172                          NaN      0.700517          TP
# 184                          NaN      0.700053          TP
# 196                          NaN      0.700020          TP
# 208                          NaN      0.700024          TP
# 220                          NaN      0.700033          TP

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Load your region-level results
region = pd.read_csv("region_results_full.csv")

# Only RidgeWalker, fusion_score notna
rw_all = region[(region["model"] == "RidgeWalker") & (region["fusion_score"].notna())]

thresholds = np.linspace(rw_all['fusion_score'].min(), rw_all['fusion_score'].max(), 100)
precision, recall, f1 = [], [], []

for t in thresholds:
    pred = (rw_all['fusion_score'] >= t)
    tp = ((pred) & (rw_all['overlap_true'])).sum()
    fp = ((pred) & (~rw_all['overlap_true'])).sum()
    fn = ((~pred) & (rw_all['overlap_true'])).sum()
    prec = tp / (tp + fp) if (tp + fp) > 0 else np.nan
    rec = tp / (tp + fn) if (tp + fn) > 0 else np.nan
    precision.append(prec)
    recall.append(rec)
    f1.append(2 * prec * rec / (prec + rec) if prec + rec > 0 else np.nan)

precision = np.array(precision)
recall = np.array(recall)
f1 = np.array(f1)

best_idx = np.nanargmax(f1)
best_t = thresholds[best_idx]

plt.figure(figsize=(10, 4))
plt.plot(thresholds, precision, label='Precision', lw=2)
plt.plot(thresholds, recall, label='Recall', lw=2)
plt.plot(thresholds, f1, label='F1', linestyle="--", lw=1.5)

# Shading the gap between precision and recall
plt.fill_between(thresholds, precision, recall, color='orange', alpha=0.15, label='Precision-Recall Gap')

plt.axvline(x=best_t, color='k', linestyle='dashed')
plt.annotate(
    f"Best F1 = {f1[best_idx]:.2f}\nFusion Score = {best_t:.2f}",
    xy=(best_t, f1[best_idx]),
    xytext=(best_t + (thresholds.max()-thresholds.min())*0.05, f1[best_idx] - 0.3),
    arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=3),
    fontsize=9,
    ha='left', va='center', weight='bold', color='black',
    bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="black", lw=1,)
)

plt.xlabel("Fusion Score Threshold")
plt.ylabel("Score")
plt.title("Precision/Recall vs. Fusion Score Threshold (RidgeWalker)")
plt.legend(
    loc='center left',
    bbox_to_anchor=(1.01, 0.5),
    frameon=True,
    title='Legend'
)
plt.tight_layout(rect=[0,0,0.75,1])
plt.show()

print(f"Best F1 = {f1[best_idx]:.2f} at Fusion Score threshold {best_t:.2f}")
# Out:
# Best F1 = 0.94 at Fusion Score threshold 0.53

# %%
# %% 
# Compute the GMM confusion‐matrix and summary metrics by high‐level scenario class

import pandas as pd

# 1) Load your per‐variant aggregated metrics
agg = pd.read_csv("aggregated_metrics.csv")

# 2) Strip the "Variant - " prefix to get bare group names
agg["base_group"] = agg["group"].str.replace(r"^Variant -\s*", "", regex=True)

# 3) Define the mapping to high‐level scenario classes
scenario_map = {
    "Two clearly separated peaks":        "Fully Separated",
    "Close but not overlapping peaks":     "Fully Separated",
    "Cluster of 3 overlapping peaks":      "Weakly Overlapping",
    "Four peaks: 2 overlap, 2 isolated":  "Weakly Overlapping",
    "Strong overlap between two peaks":    "Strongly Overlapping",
    "Intense + weak overlap":             "Asymmetric",
    "Five peaks: 3 spaced, 2 overlapping": "Near-Duplicates"
}
agg["scenario_class"] = agg["base_group"].map(scenario_map)


rw_agg = agg[agg["model"] == "RidgeWalker"]

# 5) Aggregate per scenario_class:
#    sum TP/FP/FN/TN, average F1 and Accuracy
tbl = (
    rw_agg
    .groupby("scenario_class")
    .agg({
        "tp":       "sum",
        "fp":       "sum",
        "fn":       "sum",
        "tn":       "sum",
        "f1":       "mean",
        "accuracy": "mean"
    })
    .reset_index()
)

# 6) Round the F1 and Accuracy to two decimal places
tbl["f1"] = tbl["f1"].round(2)
tbl["accuracy"] = tbl["accuracy"].round(2)

# 7) Reorder Scenario Classes as desired
order = [
    "Fully Separated",
    "Weakly Overlapping",
    "Strongly Overlapping",
    "Asymmetric",
    "Near-Duplicates"
]
tbl = tbl.set_index("scenario_class").loc[order].reset_index()
tbl
# Out:
#          scenario_class  tp  fp  fn  tn    f1  accuracy
# 0       Fully Separated   0   0   0  20  1.00      1.00
# 1    Weakly Overlapping  10   2   0   8  0.92      0.94
# 2  Strongly Overlapping   5   0   0   0  1.00      1.00
# 3            Asymmetric   3   1   2   4  0.67      0.70
# 4       Near-Duplicates   0   5   5  10  0.00      0.50

# %%
# %% 
# Color‐mapped, annotated GMM F₁ by Scenario Category

import matplotlib.pyplot as plt
import matplotlib as mpl

# Prepare values and colormap
vals = tbl["f1"].values
norm = mpl.colors.Normalize(vmin=vals.min(), vmax=vals.max())
cmap = mpl.cm.Blues

plt.figure(figsize=(6, 4))
bars = plt.bar(
    tbl["scenario_class"],
    vals,
    color=cmap(norm(vals)),
    edgecolor="black"
)

# Extend y‐axis to make room for annotations
ymax = vals.max() * 1.15
plt.ylim(0, ymax)

plt.title("Ridge Walk F₁ by Scenario Category", pad=20)
plt.ylabel("F₁-Score")
plt.xlabel("")
plt.xticks(rotation=45, ha="right")

# Annotate bar values
for bar, h in zip(bars, vals):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        h + (ymax - h) * 0.02,
        f"{h:.2f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()


# %% 
# Color‐mapped, annotated GMM Accuracy by Scenario Category

acc_vals = tbl["accuracy"].values
norm_acc = mpl.colors.Normalize(vmin=acc_vals.min(), vmax=acc_vals.max())
cmap_acc = mpl.cm.Blues

plt.figure(figsize=(6, 4))
bars = plt.bar(
    tbl["scenario_class"],
    acc_vals,
    color=cmap_acc(norm_acc(acc_vals)),
    edgecolor="black"
)

ymax_acc = acc_vals.max() * 1.15
plt.ylim(0, ymax_acc)

plt.title("Ridge Walk Accuracy by Scenario Category", pad=20)
plt.ylabel("Accuracy")
plt.xlabel("")
plt.xticks(rotation=45, ha="right")

for bar, h in zip(bars, acc_vals):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        h + (ymax_acc - h) * 0.02,
        f"{h:.2f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()
